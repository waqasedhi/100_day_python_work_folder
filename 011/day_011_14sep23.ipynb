# %% [raw]
# ############### Blackjack Project #####################
#
# #Difficulty Normal 😎: Use all Hints below to complete the project.
# #Difficulty Hard 🤔: Use only Hints 1, 2, 3 to complete the project.
# #Difficulty Extra Hard 😭: Only use Hints 1 & 2 to complete the project.
# #Difficulty Expert 🤯: Only use Hint 1 to complete the project.
#
# ############### Our Blackjack House Rules #####################
#
# ## The deck is unlimited in size.
# ## There are no jokers.
# ## The Jack/Queen/King all count as 10.
# ## The the Ace can count as 11 or 1.
# ## Use the following list as the deck of cards:
# ## cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
# ## The cards in the list have equal probability of being drawn.
# ## Cards are not removed from the deck as they are drawn.
#
# ##################### Hints #####################
#
# #Hint 1: Go to this website and try out the Blackjack game:
# #   https://games.washingtonpost.com/games/blackjack/
# #Then try out the completed Blackjack project here:
# #   http://blackjack-final.appbrewery.repl.run

# %%
import random as rd

# %%
## main code
import random as rd

starter=input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]


while starter == 'y':
    yourCards=[]
    yourScore=0
    comCards=[]
    comScore=0
    for i in range(2):
        card=0
        random1=rd.randint(0,12)
        card=cards[random1]
        if (card == 11) and (yourScore > 10):
            yourCards.append(1)
            yourScore+=1
        else:
            yourCards.append(card)
            yourScore+=card
            
    
    
    random1=rd.randint(0,12)
    comCards.append(cards[random1])
    comScore+=cards[random1]
    print(f"Your cards: {yourCards}, current score: {yourScore}")
    print(f"Computer's first cards: {comCards}")
    
    continue1=True
    while continue1:
        anotherCard=input("Type 'y' to get another card, type 'n' to pass: ")
        if anotherCard=='y':
            card=0
            random1=rd.randint(0,12)
            card=cards[random1]
            if (card == 11) and (yourScore > 10):
                yourCards.append(1)
                yourScore+=1
                if yourScore>21:
                    while not comScore >= 16:
                        card2=0
                        random2=rd.randint(0,12)
                        card2=cards[random2]
                        if (card2 == 11) and (comScore > 10):
                            comCards.append(1)
                            comScore+=1
                        else:
                            comCards.append(card2)
                            comScore+=card2
                    if comScore==yourScore:
                        continue1=False
                        print(f"Your cards: {yourCards}, current score: {yourScore}")
                        print(f"Computer's first cards: {comCards}")
                        print(f"Your final hand: {yourCards}, final score: {yourScore}")
                        print(f"Computer final hand: {comCards}, final score: {comScore}")
                        print("draw.")
                    elif comScore>yourScore:
                        continue1=False
                        print(f"Your cards: {yourCards}, current score: {yourScore}")
                        print(f"Computer's first cards: {comCards}")
                        print(f"Your final hand: {yourCards}, final score: {yourScore}")
                        print(f"Computer final hand: {comCards}, final score: {comScore}")
                        print("Oponent went over. you win")
                    else:    
                        continue1=False
                        print(f"Your cards: {yourCards}, current score: {yourScore}")
                        print(f"Computer's first cards: {comCards}")
                        print(f"Your final hand: {yourCards}, final score: {yourScore}")
                        print(f"Computer final hand: {comCards}, final score: {comScore}")
                        print("You went over. you lose")
                else:
                    print(f"Your cards: {yourCards}, current score: {yourScore}")
                    print(f"Computer's first cards: {comCards}")
            else:
                yourCards.append(card)
                yourScore+=card
                if yourScore>21:
                    while not comScore >= 16:
                        card2=0
                        random2=rd.randint(0,12)
                        card2=cards[random2]
                        if (card2 == 11) and (comScore > 10):
                            comCards.append(1)
                            comScore+=1
                        else:
                            comCards.append(card2)
                            comScore+=card2
                    if comScore==yourScore:
                        continue1=False
                        print(f"Your cards: {yourCards}, current score: {yourScore}")
                        print(f"Computer's first cards: {comCards}")
                        print(f"Your final hand: {yourCards}, final score: {yourScore}")
                        print(f"Computer final hand: {comCards}, final score: {comScore}")
                        print("draw.")
                    elif comScore>yourScore:
                        continue1=False
                        print(f"Your cards: {yourCards}, current score: {yourScore}")
                        print(f"Computer's first cards: {comCards}")
                        print(f"Your final hand: {yourCards}, final score: {yourScore}")
                        print(f"Computer final hand: {comCards}, final score: {comScore}")
                        print("Oponent went over. you win")
                    else:    
                        continue1=False
                        print(f"Your cards: {yourCards}, current score: {yourScore}")
                        print(f"Computer's first cards: {comCards}")
                        print(f"Your final hand: {yourCards}, final score: {yourScore}")
                        print(f"Computer final hand: {comCards}, final score: {comScore}")
                        print("You went over. you lose")
                else:
                    print(f"Your cards: {yourCards}, current score: {yourScore}")
                    print(f"Computer's first cards: {comCards}")

        else:
            while not comScore >= 16:
                card2=0
                random2=rd.randint(0,12)
                card2=cards[random2]
                if (card2 == 11) and (comScore > 10):
                    comCards.append(1)
                    comScore+=1
                else:
                    comCards.append(card2)
                    comScore+=card2
            continue1=False
            if comScore==yourScore:
                continue1=False
                print(f"Your cards: {yourCards}, current score: {yourScore}")
                print(f"Computer's first cards: {comCards}")
                print(f"Your final hand: {yourCards}, final score: {yourScore}")
                print(f"Computer final hand: {comCards}, final score: {comScore}")
                print("draw.")
            elif comScore>21:
                continue1=False
                print(f"Your cards: {yourCards}, current score: {yourScore}")
                print(f"Computer's first cards: {comCards}")
                print(f"Your final hand: {yourCards}, final score: {yourScore}")
                print(f"Computer final hand: {comCards}, final score: {comScore}")
                print("Oponent went over. you win")
            elif comScore>yourScore:
                continue1=False
                print(f"Your cards: {yourCards}, current score: {yourScore}")
                print(f"Computer's first cards: {comCards}")
                print(f"Your final hand: {yourCards}, final score: {yourScore}")
                print(f"Computer final hand: {comCards}, final score: {comScore}")
                print("you lose.")
            else:    
                continue1=False
                print(f"Your cards: {yourCards}, current score: {yourScore}")
                print(f"Computer's first cards: {comCards}")
                print(f"Your final hand: {yourCards}, final score: {yourScore}")
                print(f"Computer final hand: {comCards}, final score: {comScore}")
                print("you win")
    starter=input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
# Your cards: [4, 4], current score: 8
# Computer's first cards: [10]
# Type 'y' to get another card, type 'n' to pass: y
# Your cards: [4, 4, 7], current score: 15
# Computer's first cards: [10]
# Type 'y' to get another card, type 'n' to pass: y
# Your cards: [4, 4, 7, 7], current score: 22
# Computer's first cards: [10, 9]
# Your final hand: [4, 4, 7, 7], final score: 22
# Computer final hand: [10, 9], final score: 19
# You went over. you lose
# Do you want to play a game of Blackjack? Type 'y' or 'n': n

# %%
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

yourCards=[]
yourScore=0
comCards=[]
comScore=0
len(cards)

for i in range(2):
    card=0
    random1=rd.randint(0,12)
    print("random",random1)
    card=cards[random1]
    if (card == 11) and (yourScore > 10):
        yourCards.append(1)
        print("urcards",yourCards)
        yourScore+=1
        print("urscore",yourScore,)
    else:
        yourCards.append(card)
        print("urcards",yourCards)
        yourScore+=card
        print("urscore",yourScore)

# %%
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

yourCards=[]
yourScore=0
comCards=[]
comScore=0
len(cards)

# %%
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
yourCards=[10,9]
yourScore=19
comCards=[5]
comScore=0

card=0
random1=rd.randint(0,12)
print("random",random1)
card=cards[3]
if (card == 11) and (yourScore > 10):
    yourCards.append(1)
    print("urcards",yourCards)
    yourScore+=1
    print("urscore",yourScore,"\n")
    if yourScore>21:
        while not comScore >= 17:
            card2=0
            random2=rd.randint(0,12)
            print("random2",random2)
            card2=cards[random2]
            if (card2 == 11) and (comScore > 10):
                comCards.append(1)
                print("comcards",comCards)
                comScore+=1
                print("comscore",comScore,"\n")
            else:
                comCards.append(card2)
                print("comcards",comCards)
                comScore+=card2
                print("comscore",comScore,"\n")

            
            
else:
    yourCards.append(card)
    print("urcards",yourCards)
    yourScore+=card
    print("urscore",yourScore,"\n")
    if yourScore>21:
        while not comScore >= 17:
            card2=0
            random2=rd.randint(0,12)
            print("random2",random2)
            card2=cards[random2]
            if (card2 == 11) and (comScore > 10):
                comCards.append(1)
                print("comcards",comCards)
                comScore+=1
                print("comscore",comScore,"\n")
            else:
                comCards.append(card2)
                print("comcards",comCards)
                comScore+=card2
                print("comscore",comScore,"\n")

# %%
random2=rd.randint(0,12)
print(random2)
comCards.append(cards[random2])
print(comCards)
comScore+=cards[random2]
print(comScore)
print(f"Your cards: {comCards}, current score: {comScore}")

# %%
print(yourCards)
yourCards.append(1)
print(yourCards)

# %%
import random
#from replit import clear
import os
from art import logo

def deal_card():
    """Returns a random card from the deck."""
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    card = random.choice(cards)
    return card


def calculate_score(cards):
    """Take a list of cards and return the score calculated from the cards"""

    if sum(cards) == 21 and len(cards) == 2:
        return 0
    if 11 in cards and sum(cards) > 21:
        cards.remove(11)
        cards.append(1)
    return sum(cards)

def compare(user_score, computer_score):
    #Bug fix. If you and the computer are both over, you lose.
    if user_score > 21 and computer_score > 21:
        if user_score < computer_score:
            return "You win 😃"
        else:
            return "You lose 😤"


        if user_score == computer_score:
            return "Draw 🙃"
        elif computer_score == 0:
            return "Lose, opponent has Blackjack 😱"
        elif user_score == 0:
            return "Win with a Blackjack 😎"
        elif user_score > 21:
            return "You went over. You lose 😭"
        elif computer_score > 21:
            return "Opponent went over. You win 😁"
        elif user_score > computer_score:
            return "You win 😃"
        else:
            return "You lose 😤"

def play_game():

    print(logo)

    user_cards = []
    computer_cards = []
    is_game_over = False

    for _ in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())


    while not is_game_over:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)
        print(f"   Your cards: {user_cards}, current score: {user_score}")
        print(f"   Computer's first card: {computer_cards[0]}")

        if user_score == 0 or computer_score == 0 or user_score > 21:
            is_game_over = True
        else:
            user_should_deal = input("Type 'y' to get another card, type 'n' to pass: ")
        if user_should_deal == "y":
            user_cards.append(deal_card())
        else:
            is_game_over = True

    while computer_score != 0 and computer_score < 17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)

    print(f"   Your final hand: {user_cards}, final score: {user_score}")
    print(f"   Computer's final hand: {computer_cards}, final score: {computer_score}")
    print(compare(user_score, computer_score))

    while input("Do you want to play a game of Blackjack? Type 'y' or 'n': ") == "y":
        #clear()
        os.system('cls' if os.name == 'nt' else 'clear')
        play_game()
play_game()
# Out:
#
#  ,adPPYba, ,adPPYYba,  ,adPPYba, ,adPPYba, ,adPPYYba, 8b,dPPYba,
# a8"     "" ""     `Y8 a8P_____88 I8[    "" ""     `Y8 88P'   "Y8
# 8b         ,adPPPPP88 8PP"""""""  `"Y8ba,  ,adPPPPP88 88
# "8a,   ,aa 88,    ,88 "8b,   ,aa aa    ]8I 88,    ,88 88
#  `"Ybbd8"' `"8bbdP"Y8  `"Ybbd8"' `"YbbdP"' `"8bbdP"Y8 88
#
#            88             88
#            ""             88
#                           88
#  ,adPPYba, 88 8b,dPPYba,  88,dPPYba,   ,adPPYba, 8b,dPPYba,
# a8"     "" 88 88P'    "8a 88P'    "8a a8P_____88 88P'   "Y8
# 8b         88 88       d8 88       88 8PP""""""" 88
# "8a,   ,aa 88 88b,   ,a8" 88       88 "8b,   ,aa 88
#  `"Ybbd8"' 88 88`YbbdP"'  88       88  `"Ybbd8"' 88
#               88
#               88
#
#    Your cards: [7, 10], current score: 17
#    Computer's first card: 5

# %%
lst =[]
for i in range (1,101)
    lst.append(i)

# %%
print(lst)
